# %%
import requests
import random

import pandas as pd

# %%
# queries the socrata data api for Denver Nonprofits founded in the past 6 years
url = 'https://data.colorado.gov/resource/4ykn-tg5h.json?entitytype=Nonprofit Corporation&principalcity=Denver&$where=date_extract_y(entityformdate) > 2014&entitystatus=Good Standing'
res = requests.get(url)
df = pd.json_normalize(res.json())
df.head()
# Out:
#       entityid                            entityname  principaladdress1  \
# 0  20201234386  Urban Sanctuary Denver Nonprofit Inc     2745 Welton St
# 1  20201236103   Mind Over Matter (M.O.M.) Athletics  1995 Rosemary St.
# 2  20201237742                  Adelitas de Colorado    1601 s yates st
# 3  20201238149                      YAMAN FOUNDATION     20421 Kelly pl
# 4  20201238996                      Connect Colorado  3233 S Glencoe St
#
#   principalcity principalstate principalzipcode principalcountry  \
# 0        Denver             CO            80205               US
# 1        Denver             CO            80220               US
# 2        Denver             CO            80219               US
# 3        Denver             CO            80249               US
# 4        Denver             CO            80222               US
#
#     entitystatus jurisdictonofformation             entitytype  ...  \
# 0  Good Standing                     CO  Nonprofit Corporation  ...
# 1  Good Standing                     CO  Nonprofit Corporation  ...
# 2  Good Standing                     CO  Nonprofit Corporation  ...
# 3  Good Standing                     CO  Nonprofit Corporation  ...
# 4  Good Standing                     CO  Nonprofit Corporation  ...
#
#   agentmailingaddress1 agentmailingcity agentmailingstate agentmailingzipcode  \
# 0                  NaN              NaN               NaN                 NaN
# 1       P.O Box 200952           Denver                CO               80220
# 2                  NaN              NaN               NaN                 NaN
# 3                  NaN              NaN               NaN                 NaN
# 4                  NaN              NaN               NaN                 NaN
#
#   agentmailingcountry agentmiddlename principaladdress2 agentmailingaddress2  \
# 0                 NaN             NaN               NaN                  NaN
# 1                  US             NaN               NaN                  NaN
# 2                 NaN             NaN               NaN                  NaN
# 3                 NaN           Magne               NaN                  NaN
# 4                 NaN         Michael               NaN                  NaN
#
#   mailingaddress2 agentsuffix
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
#
# [5 rows x 35 columns]

# %%
df.dtypes
# Out:
# entityid                  object
# entityname                object
# principaladdress1         object
# principalcity             object
# principalstate            object
# principalzipcode          object
# principalcountry          object
# entitystatus              object
# jurisdictonofformation    object
# entitytype                object
# agentorganizationname     object
# agentprincipaladdress1    object
# agentprincipaladdress2    object
# agentprincipalcity        object
# agentprincipalstate       object
# agentprincipalzipcode     object
# agentprincipalcountry     object
# entityformdate            object
# mailingaddress1           object
# mailingcity               object
# mailingstate              object
# mailingzipcode            object
# mailingcountry            object
# agentfirstname            object
# agentlastname             object
# agentmailingaddress1      object
# agentmailingcity          object
# agentmailingstate         object
# agentmailingzipcode       object
# agentmailingcountry       object
# agentmiddlename           object
# principaladdress2         object
# agentmailingaddress2      object
# mailingaddress2           object
# agentsuffix               object
# dtype: object

# %%
df.shape
# Out:
# (1000, 35)

# %%
df.principalcity.unique()
# Out:
# array(['Denver'], dtype=object)

# %%
list(sorted(df.entityname, key=lambda x: random.random()))
# Out:
# ['CHILDREN PHYSICAL FITNESS ASSOCIATION',
#  'Denver Democratic Socialists of America',
#  'Northeast Denver Childcare Network',
#  'National Trust for Local News',
#  'Independent Action',
#  'Colorado Visionaries Blind Hockey Club',
#  'McGregor Square Office Condominium Association, Inc.',
#  'Harmonist Sanctuary',
#  'Chelkou Amarrat Community Association',
#  'BPM Foundation, Inc',
#  'Denver Pipefitters Joint Apprenticeship',
#  'ROBERTS FAMILY FOUNDATION',
#  'Denver Hockey Academy',
#  'THE BELIEVERSTEMPLE(TBT)',
#  'Chernowitz Medical Research Foundation, Inc.',
#  'Life Victory Ministry',
#  'Atlas at Boulevard One HOA, Inc.',
#  'Association for Institutional Thought',
#  "Stain'd",
#  'Scotties Home Improvements',
#  'Coloradans for Colorado Values',
#  'Promontory Homeowners Association, Inc.',
#  'Mountain View Tower LRC',
#  'FEEX FINANCIAL FOUNDATION',
#  'Chabad Lubavitch of Colorado, Inc.',
#  'Coloradans for Coloradans',
#  'THE G-CODE',
#  'Harvest Ridge at Indian Peaks Homeowners Association',
#  'Culinary Hospitality Outreach and Wellness, Inc',
#  'The Deputy Heath Gumm Foundation',
#  'Allies Every Day',
#  'Solomon Faith International',
#  '3 Pillars Initiative, Inc.',
#  'Joe Shoemaker School Parent Teacher Organization',
#  'SILVER WILLOW FOUNDATION',
#  'Muso asset investment foundation',
#  'Explore',
#  'Tepeyac QALICB, Inc.',
#  'The Women In Fitness Association',
#  'Museum of Food and Culture',
#  'Colors Of Rainbow',
#  'American Adjuster Association, Inc.',
#  'RipMode Skwad Inc.',
#  'Skot Foundation',
#  'Colorado Tax Center',
#  'RV4campfirefamily Inc.',
#  'CENTER TO ADVANCE IDEOLOGICAL DIVERSITY',
#  'Side Stories, Inc.',
#  'Club El Azul Inc.',
#  'Front Range Area Health Education Center',
#  'Resilient Communities. Resilient Futures, Inc.',
#  'Colorado Corgis and Friends',
#  'ViVe',
#  'Grant Source of Denver',
#  'MILE HIGH OILMANS GOLF TOURNAMENT',
#  'UNCC International Foundation',
#  'BWC FOUNDATION',
#  'Grant Street Music Collaborative',
#  'Up-Cycled Co.',
#  'Blessed to Be a Blessing',
#  'Platte 56 HOA, LLC',
#  'The Parker Stokes Foundation',
#  'House of Mercy',
#  'Foundation and Ministry of L.I.F.E. (Limitless Ideas and Free Environments)',
#  'Morey Residents Coalition Corp',
#  'Miracle Holdings Limited',
#  'Heart Christian University Corp',
#  'KEPLER-22 FOUNDATION LIMITED',
#  'River Crossing at Rendezvous Homeowners Association, Inc.',
#  'SW GAA Inc.',
#  'Jin Merchants Entire Globe Foundation',
#  'Platinum Divaz Dance Company',
#  'Colorado Lions Youth Organization Inc.',
#  'The Pearl Condominiums Association, Inc.',
#  'Voice of the Congolese Orphans',
#  'Power Moves Unlimited Mentoring Foundation',
#  'Friends of CU Athletics',
#  'Colorado Black Leadership Caucus',
#  'RISE Nonprofit',
#  'The COMMIT Foundation',
#  'Arriba Cabarete',
#  'American Mid-West Culinary Federation',
#  'G2',
#  'The Center for Social Creativity',
#  'someone worth knowing association',
#  'Center for American Jewish Poetry',
#  'The Retreat at Wildwing Homeowners Association, Inc.',
#  'SUMMER RAE ANIMAL RESCUE COMPANY',
#  'Capernaum Church',
#  'Cannabis Trade Federation Action',
#  'On All Sides',
#  'GRACE COUNSELING HOME SERVICES',
#  'vibe tribe adventures',
#  'Center for Community Wealth Building',
#  'conceptslearningmachine',
#  'TIL INTERNATIONAL FOUNDATION',
#  'Nuclear Fusion Project',
#  'CASTAWIDE INC',
#  'The Colorado Foundation',
#  "Denver Interdenominational Association of Ministers' Wives and Ministers' Widows",
#  'Madre sin Limites Corporation',
#  'Raabe Family Dentistry Charitable Foundation',
#  'LifeRing Colorado, Inc.',
#  'Blaze Entertainment',
#  'Spirit of Colorado',
#  'ArtistiCO Inc.',
#  'SEIU 775 Benefits Group',
#  'LNC INTERNATIONAL FOUNDATION',
#  'The Orpheus Condominium Association, Inc.',
#  'Mind Over Matter (M.O.M.) Athletics',
#  'Rocky Mountain Veterans Advocacy Project, Inc.',
#  'Colorado Readiness Council',
#  'Denver School Leaders Association',
#  'Ruachis',
#  'Committee to Protect the Electoral College',
#  'Matador-Atlas Boulevard One HOA, Inc.',
#  'Lienzo Charro El Paraiso, Inc.',
#  'San Sophia West Filing No. 2 Association',
#  'Make It Make Sense, Inc.',
#  'Connect Colorado',
#  'CO Event Alliance',
#  'Lance Ramsay Raymond Foundation',
#  'The Ivy Residences Association',
#  'Rocky Mountain Threadshare',
#  'Denver Full Belly Company',
#  'Forward Julesburg Inc.',
#  'National Immigrant Victory Fund',
#  'Townhomes at Virginia Village Homeowners Association, Inc.',
#  'Avodah Farms',
#  'Evanelia Tahiti Inc.',
#  'jneighbor',
#  'Undestructable',
#  'HULK INDUSTRIES',
#  'United Minority Leadership in Sports Council Inc.',
#  'Papa Al Corporation',
#  'Fishing the Good Fight, Inc.',
#  'ETWF, Inc.',
#  'Timbers at The Pinery Filing No. 29B Homeowners Association, Inc.',
#  'Equity Farms Inc.',
#  'The Bison Foundation',
#  'Planting Seedz',
#  'The Invictus Project',
#  'FrEekys rolling trays and Accessories',
#  'Warriors Foundation, Inc.',
#  'World From Scratch',
#  'Saint Joseph Hospital Auxiliary',
#  'Earthworks Action Fund',
#  'Polyvagal Institute',
#  'BUNNYGIRL CERTIFICATION INSTITUTE',
#  'Colburn Condominium Association',
#  'Piper Inn Staff Supplement for Emergencies and Disasters Corp.',
#  'Haven Media Inc.',
#  'Ironton Street Townhomes Homeowners Association, Inc.',
#  'Legacy Lofts Housing Corporation II',
#  'American Legion Post 5280',
#  'Colorado Artists in Recovery',
#  'Veterans of Foreign Wars Skyline Post 2797',
#  'Gamayun Corporation',
#  'The Grace House Inc',
#  'Pro Police Rally Colorado',
#  "Mask America's Kids",
#  'Adult Vape Advocacy, Inc.',
#  'Open Arms Assisted Living',
#  'Neighbors In Need Corp.',
#  'Colorado Divas Softball',
#  'Veterans Advocacy of Benefits Organization, Ltd.',
#  'DENVER SISTERS CIRCLE',
#  'Front Range Conservatives',
#  'Flipping For Downs Inc.',
#  'AMERICAN COUNCIL OF ENGINEERING COMPANIES OF COLORADO SCHOLARSHIP AND EDUCATION FOUNDATION',
#  'Wine Oil Bread 4 Heart',
#  'melchizedek chapter dok',
#  'Adelitas de Colorado',
#  'Praeambula Network',
#  'Asian Architectural Heritage Foundation',
#  'I.M.P.A.C.T. Re-Entry, Inc.',
#  'Tapiz LRC',
#  'Denver Lab School',
#  'Mike Tyson Cares, Inc.',
#  'The Righteous Project inc.',
#  'Prince North Building Association, Inc.',
#  'Mental Health Center of Denver Employee Hardship Fund',
#  'Denver Friends, Inc.',
#  'Elevated Thinking For Success',
#  'National Council of Military Fraternities and Sororities Inc.',
#  'PRUDENTIAL FOUNDATION (USA) LTD',
#  'High Life Christian Center',
#  'Lepus Capital Foundation',
#  'Benchmarking the Ethereum Foundation',
#  'Dayton Street Commercial Condominium Association, Inc.',
#  'Colorado Leads, Inc.',
#  'Lucy',
#  'Public Domain Theater Co.',
#  'Creative Hearts Creative Minds Early Learning Center',
#  'Monarch Building Corporation',
#  'North American Hostel Association',
#  "Citizens to Save Governor's Park",
#  'Pro Cyclist Foundation',
#  '20 Jay St Condo Assn',
#  'Gatehouse Fellowship',
#  'Quigg Newton Homes LRC',
#  'Beautiful Feet Wellness',
#  'The Color of Cannabis Colorado',
#  'Teacup Wellness Nonprofit',
#  'Project Taper Inc.',
#  'Future In Front of Us Resource Center & "K" care',
#  'LANK INTERNATIONAL FOUNDATION',
#  'Mai Hope Inc.',
#  'Founders MOB Owners Association, Inc.',
#  'Smart Growth Initiative Inc.',
#  'Energize Our Economy',
#  'Making Colorado Work Again A Non Profit Corporation',
#  'L.E.A.D.S',
#  'Convivir Colorado',
#  'LULU ONE, INC.',
#  'World Destiny International Ministries - West',
#  'GoodCinema',
#  'The Shabbat Experience',
#  'Rendezvous Center Condominium Association, Inc.',
#  'Colorado Criminal Justice Reform Coalition 4 Action',
#  'Diabetes Support Network, Inc.',
#  'Centro Cristiano Betesda',
#  'BevyWork',
#  'Good Business Colorado',
#  'The Veterans Legal Center of the Rockies, Inc.',
#  'American Indian Academy of Denver Foundation',
#  'McAuliffe Manual Middle School Foundation',
#  'Walking Out Of Darkness Into Jesus Marvellous Light Ministries',
#  'CORHIO Health Current NewCo',
#  'Green Economy Development Foundation',
#  "The Mike's Mile Foundation",
#  'Valley Animal Friends',
#  'The One Project',
#  'Holm Helpers',
#  'Kobu Foundation',
#  'Yes on 2A: Climate Action Now',
#  'United Nations Epidemic Prevention Material Deployment Organization',
#  'Ability to Transfer Non-Profit Corporation',
#  'AMERICAN CHRONIC DISEASE REHABILITATION MANAGEMENT CENTER',
#  'Open Digital Finance Foundation',
#  'MSconnext Foundation',
#  'The Audacity For Transparency Corp',
#  'MWRS Foundation',
#  'The Anti-Gideon Society Inc.',
#  'Sunshine foundation',
#  'Deep Well Church',
#  'North Lincoln Midrise LRC',
#  'The Rows at Arista Community Association',
#  'The Generative Futures Initiative',
#  'RTD Celebration Fund',
#  'Amigas In Action',
#  'Trenton Townhomes Homeowners Association, Inc.',
#  'Cybersemics Institute Inc',
#  'No Hungry Poor, LLC',
#  'Lady Clark\'s Community Service - "We Got Your Back Team" Inc.',
#  'African American Catholic Congregation - Imani Temple of Denver, Inc',
#  'Stout24 Rowhomes Homeowners Association, Inc.',
#  'Project Send It',
#  'Colorado Soccer Community Incorporated',
#  'Built2Prosper',
#  'Rifle Heights Community Association, Inc.',
#  'Research Initiatives for Development Education',
#  'Palisade Park Community Association, Inc.',
#  'Hemp Reimagination Organization',
#  'Denver Fire Department Federal Credit Union',
#  'Fast for Feast, Inc.',
#  'Mays/Graham Family Reunion Committee , Inc',
#  'One Hope',
#  'Denver Oilfield Xmas Corporation',
#  'Caring for Colorado Centennial Fund',
#  'The Guidehouse Foundation Inc.',
#  'WERKER INC.',
#  'Taiva Professional Complex Building 3 Association, Inc.',
#  'The Asian Chamber Foundation of Colorado',
#  'Tomorrow Link',
#  'Querencia Community Foundation',
#  'South Park Rail Society',
#  'Broadway Arkansas Condominium Association, Inc.',
#  'Manzi Soccer Academy',
#  'Progressive Voters Guide Ballot Independent Expenditure Committee',
#  'Address Climate Change by Earnestly Planting Trees (ACCEPT)',
#  'Colorado Technology Student Association Alumni Association',
#  'COMPASSIONATE COLORADO',
#  'LeadImpact Christian College',
#  'WANDLER FAMILY FOUNDATION',
#  'Colorado Society of Clinical Hypnosis',
#  'Dark Lions LLC',
#  'EduLIBER',
#  'CCJRC4ACTION',
#  'Success Mindset Institute Inc.',
#  'Lincoln Hills Cares',
#  'Grand Slam Foundation',
#  'Purified Solutions and Paradise Inventions Inc',
#  'Helping Hands for Dignity Coalition',
#  'Prosperous Wellington',
#  'Colorado Chinese Mutual Support Association',
#  'Fund the Fight',
#  'Movement By TOB',
#  'STUDENT HEALTH INVESTMENT PARTNERS INC.',
#  'CLCS Action',
#  'The Sacred House of Eden',
#  'Kappa Sigma Fraternity of the West Denver Colony',
#  'Love Wins',
#  'Sober Apartment Living, Co.',
#  'The Wellspring of Joy International Ministry',
#  'GreenHaus Owners Association',
#  'this is home',
#  'ESTHER Fund, Inc.',
#  'Community Gives, Inc.',
#  "North Denver Knight's",
#  'Next Is Now',
#  'THE SUSAN E. STANTON FOUNDATION',
#  'Clay Lady Solutions',
#  'The Colorado Organization for the Treatment of Opioid Dependence',
#  'Montview Townhomes Homeowners Association, Inc.',
#  'Foundation for Black Entrepreneurship',
#  'Tasteful Smile Dentistry, Inc.',
#  'Centennial State Prosperity',
#  'Ministerios Nuevos Comienzos',
#  'East Pointe Subdivision Owners Association, Inc.',
#  "Colorado Women's Chamber Foundation",
#  'Colorado Soldiers Youth Activities',
#  'Primavera Place: A Suzuki Music School',
#  'Women on the Rise',
#  'FIELD OF DREAMS COLORADO',
#  'Xanthia Way Townhomes Homeowners Association, Inc.',
#  "Karl's Farm Homeowners Association, Inc.",
#  'Henry and Baloo Foundation',
#  'The Flatiron Foundation',
#  'BOULEVARD ONE TOWNHOMES AT LOWRY OWNERS ASSOCIATION, INC.',
#  'Moczo Motorsports',
#  'Por Vida Marriage Ministry',
#  'Westwood Homes LRC',
#  'Olympus Foundation Inc.',
#  'One Promise Foundation',
#  'Ministerio Casa De Dios Co.',
#  'Mass Integration, Inc.',
#  'DMC Outreach Center, Corporation',
#  'United Northeast Denver Residents',
#  'HOUSE OF SHILOH ASSEMBLY',
#  'Islamic Outreach Center of Colorado (IOCC)',
#  'CV Network Communications Inc.',
#  'Cold Cap Advocacy Denver',
#  '3G Financial',
#  'REAL Academy of Art Colorado',
#  'The Last Prisoner Project',
#  'Denver Field Alignment Council',
#  'Global Ecological Cycle Foundation',
#  'Denver Hybrid College',
#  'Cambodian Buddhist of Colorado',
#  'JMXE Community Foundation, Inc.',
#  'A Hand Up Not A Hand Out Spiritual Warfare Ministries',
#  'George Floyd Justice Center',
#  'Sterling Ranch Filing 2 Homeowners Association, Inc.',
#  'Greenwood Advisors',
#  'Denver Asian Collective, Inc.',
#  'Denver Misfits Rugby Football Club',
#  'Fresh Ed Experiences, Inc.',
#  'Colorado Restaurant Association Steamboat Springs Chapter',
#  '3Durans Foundation',
#  'Milky Way Foundation',
#  'Corporate Pride Network of the Rockies',
#  'Center of The Rockies',
#  'Relentum Foundation',
#  'Duran for Congress',
#  'Initium Cares',
#  'Denver Fringe Festival, Inc.',
#  "Colorado People's Action PAC",
#  'MISS UNIVERSE FASHION ORGANIZATION',
#  'Destiny kouame ministries',
#  'plant THe Cure radio, Ltd.',
#  'Tangible Reparations Act',
#  'Black Colorado Inc.',
#  'AHI Development Golden West Inc.',
#  'Infrastructure Education Council',
#  'SSRC Corp.',
#  'Boss Generation',
#  'Michael Jones Gives',
#  'QTQ Foundation',
#  "Sphinx's Riddle Theatre Company",
#  'Horse Savior, Inc',
#  'US Hemp Building Foundation',
#  'Taiva Professional Complex Building 2 Association, Inc.',
#  'Water Design Build Council, Inc',
#  'Senior Care Review',
#  'Physical Education Professionals (PEP), Inc.',
#  'FOCUS SEARCH TECHNOLOGY LTD.',
#  'The Gift of Hope Foundation Inc.',
#  'National Association of Forensic Autopsy Technicians',
#  'Black Sex Workers of Colorado',
#  'Minorities Matter in Agricultural Farming & Natural Resources',
#  'P.U.S.H',
#  'C-Urchin Foundation',
#  'Denver metro modern quilt guild',
#  'Grit On Grease',
#  'Cherishing Life Youth Transformation Services',
#  'O.T.O.M.S. Original Teachings of Moorish Science',
#  'PATH, Inc.',
#  'Finemind',
#  'Colorado Financial Services Association',
#  'MHMP Clare',
#  'OAC INTERNATIONAL FOUNDATION',
#  'SCD Enrichment Program',
#  'Barton Institute for Community Action',
#  'RK Cares Hardship Fund',
#  'The JEKL Institute',
#  'Quid Pro Care',
#  'McGregor Square Hotel Condominium Association, Inc.',
#  'Cancersofblood.org',
#  'Super Medium Institute',
#  'Confluence Infinite International',
#  'Women Who Charge',
#  'Central Park Flats Association',
#  'Rose Foret Co.',
#  'Trinity Lutheran Church Denver',
#  'The National Black Adventure Directory',
#  'LOVE DELIVERY FOUNDATION',
#  'AAEIO Initiative Ltd',
#  'The Boulevard IV Community Association',
#  '1000 Black Men that Lead, Corp',
#  'New Greater Harvest Church Of God In Christ',
#  'Heal the Hood',
#  'Black Lives Matter 5280',
#  'ViV Global Hydration Project Inc.',
#  'Her Higher Self',
#  'Aya Foundation',
#  'WITT Were In This Together',
#  '2880 Zuni Owners Association',
#  "Let's Get Colorado Back To Business",
#  'Colorado Changemakers Collective',
#  'Unique Community Care Center',
#  'Greyhound Park Community Association Inc.',
#  'Needle & Frame Inc.',
#  'Chaffee Park RNO',
#  'The Louis and Harold Price Foundation, Inc.',
#  'Faro A Las Naciones, Inc.',
#  'We Agree on Three Inc.',
#  'Denver Delivery Network',
#  'Cloud Cover',
#  'Louisville Corporate Campus Owners Association',
#  'DENVER GOOD NEWS',
#  'ETIV Inc.',
#  'Elevation Community Land Trust',
#  'Promoting Parent Advocacy',
#  'Moline Street Townhomes Homeowners Association, Inc.',
#  'Americas Center for the Arts (ACA)',
#  'HOREFONDE ASSOCIATION OF THE UNITED STATES',
#  'Hour of Hope Christian Center',
#  'RETROSPEKT FESTIVAL INC',
#  'The Gnarly Barkles Foundation',
#  'We And My Friends, Inc.',
#  'lavizzo eductional alliance platform',
#  'STEAD School Building Corporation',
#  'Overlook at Cherry Creek - Parker Homeowners Association, Inc.',
#  'Colorado REACH Conference',
#  'Gymtegrity Gymnastics Booster Club',
#  'Tremont Place HOA',
#  'GOSPEL TRUTH BIBLE MINISTRY CORP.',
#  "Colorado's District Attorney Association Action",
#  'PIRATES WRESTLING',
#  'SAFER Colorado',
#  'Ms. Jae Consults',
#  'WG Ministries Inc.',
#  'StepChange Impact Corp.',
#  'Public Bark Inc',
#  'Colorado Small Business Coalition',
#  'KAVOD-Ensuring Dignity for Holocaust Survivors',
#  'Ministerio Internacional Fuego Purificador',
#  'Wonder',
#  'For The Birds',
#  'World Home for Orphans',
#  'Cook Park Community Garden',
#  'The Onyx Project',
#  'Elevation Ministries Denver',
#  'YourChat Foundation',
#  'DEvelyn Jags Football Quarterback Club',
#  'Denver Chamber Music Festival',
#  'Palmer Elementary Parent Teacher Association',
#  'The Young Excellence and Success Foundation',
#  "L'Ecole de Denver",
#  'SoBo 58 Homeowners Association',
#  'Progressive Voters Guide Ballot Committee',
#  'The Tica Project',
#  'Northwest Denver Education Committee',
#  'Omnicloud International Foundation',
#  'Thomas Dance Project Corp.',
#  '(FSF) Futuristic Safety First',
#  'Macanta Community Association, Inc.',
#  'Agua Libre',
#  'Blue Wagon Community',
#  'Buffett Foundation',
#  'Heidi Phillips Foundation',
#  'Center for Social Impact Innovation',
#  'Fork A Meal',
#  'Enter The Dragon, LLC',
#  'Davenport Ranch Properties Owners Association, Inc.',
#  'Voice Of Social Media Ltd',
#  'Body of Christ Community',
#  'Nia Reign Ministries, Inc.',
#  'COLLECTIVE COMMONS ALLIANCE',
#  'CON-X-SHUNS',
#  "God's Spirit Mountain Men's Group",
#  'Security Officers Association of America',
#  'Logan and Bayaud Condominiums Association, Inc.',
#  'For the Love of Birds Rescue & Sanctuary',
#  "The Colorado People's Lawyer Fund",
#  'The National Arab American Association of Engineers and Architects (Colorado Chapter)',
#  'Volleyball Internacional',
#  'Amel for Health Promotion and Education',
#  'Portrait at Stapleton Filing 49 Homeowners Association, Inc.',
#  'Ability Connections Inc',
#  'United Faith Christian Fellowship',
#  'Buell Public Media Center Owners Association',
#  'Black Men That Lead',
#  'US Cultural Tourism Foundation',
#  'Swing Away Charities',
#  'Spark Discipleship Inc',
#  'American Global Academy',
#  'Western Way Action',
#  'NOW HOW Group',
#  'Yes We Can Help',
#  'Burmese Islamic Association of Colorado',
#  'Walsh Firefighters Association',
#  'Lady Regulators',
#  'Monarca',
#  'Universal Learning Institute',
#  'DBRW Group',
#  "Mile High Writers' Workshop, Inc.",
#  'Mountain Peaks Inc.',
#  'Editone zone!!',
#  'Cross Creek Homeowners Association, Inc.',
#  'Bicycles for Children Inc.',
#  'Namastage Theatre',
#  'Culture Brigade',
#  'Western States College of Construction',
#  'Urban & Elite Entertainment Inc.',
#  'CorpsGiving Foundation',
#  'Up Pup and Away, Inc.',
#  'The Heights Community Church Inc.',
#  'REDEMPTION GHANAIAN PRESBYTERIAN CHURCH DENVER CO',
#  'Minimize Mindfully',
#  'Rocky Mountain Mechanical Contractors Association',
#  'Literacy Consultants Coalition',
#  'Colorado Medical Disaster Relief Foundation',
#  'Education Policy Project',
#  'Pathos Labs',
#  'Colorado Name Change Project',
#  'MNG Summit',
#  'ROCKY MOUNTAIN VALUES',
#  'Sudan Volunteer Organization(SVO-USA)',
#  'Career Factor Institute',
#  'Defending America',
#  'CMP FOUNDATION',
#  'Free the Oppressed',
#  'Optimal Innovation Group',
#  'Socks for Denver Incorporated',
#  'Project hope(Haven-Of-Hope) Center',
#  'International Children Roller Skating Association',
#  'Republican Commissioners for Colorado',
#  'Compositive Project',
#  'Urban Sanctuary Denver Nonprofit Inc',
#  'BMW Help Foundation',
#  'Beeler Park Rows I Community Association',
#  "Adam's Purpose",
#  'Greater Legacy Christian Fellowship, Inc.',
#  'LuvFromLily',
#  'Universal Service Administrative Co.',
#  'Rendezvous Center Master Association, Inc.',
#  'Solis Townhomes Homeowners Association, Inc.',
#  'PTA COLORADO CONGRESS TELLER ELEMENTARY SCHOOL PTA',
#  'Front Range Conservation, Inc.',
#  'Digital Globalization Consortium, Inc',
#  'Gold Rush Foundation',
#  'IDEX GLOBAL FOUNDATION',
#  'Glacier Rescue Project',
#  'ICey Foundation',
#  "BLACKSTONE RANCH FILING NO. 4 HOMEOWNERS' ASSOCIATION",
#  'Manifold Press',
#  'Abundance Foundation, Inc.',
#  'Hungry Homeless Solutions LLC',
#  'FORSAKEN SOULS MOTORCYCLE CLUB LLC',
#  'Unicorn Exchange',
#  'Academy Colorado',
#  'Wakanda Saturday STEM Program',
#  'Youth Empowerment Broadcasting Organization',
#  'Atoma Preschool',
#  'GGP global foundation ,',
#  '38th and Lowell Association',
#  'Walsh Annex LRC',
#  'Little Journeys Foundation',
#  "Settler's Crossing Master Owners Association, Inc.",
#  'Signal Tech Coalition',
#  'Honoring Our Mothers Equally',
#  'GRIT, Inc.',
#  'Citizens for a Responsible Denver',
#  'Common Sense',
#  'Thomas Bean Tower LRC',
#  'Adolescents Know Your Rights',
#  'LEAVE THE PAST BEHIND INC',
#  'Davis Foundation PVBPS - Pro Veritas, Bonitas, Pulchritas, Sanctitas',
#  'Parkview Residences Owners Association',
#  "The Next Thing Smokin' Foundation",
#  'Sunlight Transport Initiative',
#  'East Bend Homeowners Association, Inc.',
#  'La Corte Imperial de la Corona de Borbon y Vizcaya Internacional Inc',
#  'Suzan and Michael Geller Family Foundation',
#  'Klarisana Outreach Inc.',
#  'Color of Fashion',
#  'Hands Inspired',
#  'Cliff Effect',
#  'Fusion Studios Housing Corporation',
#  'Our Denver, Our Schools',
#  'Recreation Association of the Denver Division',
#  'Black Capital Foundation',
#  'Harvest Village Townhomes Subassociation, Inc.',
#  'Diversifying Our Communities Inc.',
#  'Sacred Tree Fowl Utilities P.C.',
#  "Colorado People's Action Federal PAC",
#  'Palikari Protection, Inc',
#  'Gerald R. Armstrong Foundation',
#  'Uplands Community Collective',
#  'The Standard',
#  'Project Coalesce Inc.',
#  'Exclusive Assistance Fund',
#  'Healing Touch Home Care Services',
#  'The Initiative',
#  'Bring Them In Ministries',
#  'Win Easily International Foundation',
#  'KeWiTo Charitable Holdings Limited',
#  'North Highland Open Table: A Fellowship of Seekers, Inc.',
#  'Rocky Mountain Public Media QALICB, Inc.',
#  'Camberwell Cares Incorporated',
#  'Kappa Phi Lambda Sorority, Inc.',
#  "MADEIRA ROW HOMEOWNERS' ASSOCIATION, INC.",
#  'Reynolds Capital Foundation',
#  'Concept E-3...Nature Restored, Ltd',
#  'L.E.M.O.N.S',
#  'Amanda Sandoval for Council',
#  'DENVER METRO LEAGUE',
#  'Colorado Organization for Latina Opportunity and Reproductive Rights (COLOR) Action Fund',
#  'Truedreams',
#  'USA Saifushi Corporation Foundation',
#  'Tiny Spoon',
#  'Iglesia Rios De Uncion, Inc',
#  'BRANDON AND WENDY JOHNSON FAMILY FOUNDATION',
#  'Starfish Foundation, Inc.',
#  'With Strangers',
#  'Auxilia Foundation',
#  'AllSafe Foundation',
#  'Tava Holdings Corporation',
#  'Colorado Common Sense County Leadership',
#  'Greater Kingdom Fellowship International Inc.',
#  'Cabrini Day Holiday Commission',
#  'ss-sm foundation',
#  '7th Avenue Neighborhood Association',
#  'Fair Lines Colorado',
#  'We Ride 4, Denver',
#  'Take Note Colorado',
#  'Accelerate Neighborhood Climate Action',
#  'Sierra Club Small Donor Committee',
#  'Intersection at Stapleton Homeowners Association, Inc.',
#  'Colorado Infrastructure Coalition',
#  'Beyond Betty, Inc.',
#  'Townhomes at Trailside on Harmony',
#  'Kids Life Inc',
#  'Greater Denver CARES Circle of the National CARES Mentoring Movement Inc.',
#  'Springboard Child Care, Inc.',
#  'Our Front Porch',
#  'Solutions for Colorado',
#  'Denver Anti Racist and Reconciliation Training',
#  'Freed fintech Foundation',
#  'Climate Justice Colorado',
#  'National Hispanic Cannabis Council',
#  'Seasoned With Grace UnBoxed Inc',
#  'SOS Employee Relations Committee',
#  'Collective Church',
#  'BITs EXCHANGE',
#  'CO Active, Inc.',
#  'Radical Arts Academy of Denver (RAAD)',
#  'Heart to Heart VA Homes',
#  'Peak Pentathlon',
#  'Universal Life Church Denver',
#  'Western Slope First',
#  'Mother of Corals Inc.',
#  'Stop the Violence Foundation',
#  'Colorado Local Business Coalition',
#  'Reimagine Humanity Inc',
#  'Authentically Chosen',
#  'African American Trade Association, Inc.',
#  'Smooth Carpet Cleaning and Restoration',
#  'Four Corners Empire of la Corte Imperial de Borbon y Vizcaya , Inc',
#  'Signal Climate Coalition',
#  'Korean Pastors Pension Fund, Inc.',
#  'River Deep Foundation',
#  'Westridge Homes LRC',
#  'Nu Alpha Kappa Fraternity Inc., Alpha Gamma Chapter',
#  'Colorado Avalanche Alumni Association',
#  'Flats at VillaRosso Association',
#  'Pronghorn West Commercial Owners Association, Inc.',
#  'Covid Clinic, Inc.',
#  'Arapahoe Hockey Inc',
#  'Coalition for International Conservation',
#  'TEAM Players Inc.',
#  'H.O.M.E - Home Ownership Made Easy',
#  'Beeler Park Rows II Community Association',
#  'Climate Action Denver',
#  'Teddy Bruce Memorial Fund',
#  'Organic Cannabis Association',
#  'Echinacea Montessori School',
#  'SSS Education Corp.',
#  'THE ELEVATED CONSCIOUSNESS OF ASTROLOGY & SACRED CRYSTAL INC.',
#  'Urban Tikkun Centre',
#  'RMALSB',
#  "Cayleb's Kindred Senior Dog Rescue",
#  'ConnectED Colorado',
#  'Abdominal Core Health Quality Collaborative',
#  'Project Restart Inc.',
#  'SUPER SHELTER INC',
#  'Buisson Ardent Church',
#  'Colorado Product Foundation',
#  'J - Square Presents',
#  'Harmony Master Homeowners Association, Inc.',
#  'Speed network foundation',
#  'Every Day Improving Youth Lives',
#  'Colorado Fertility Advocates',
#  "Denver's Own Museum of Sex Inc.",
#  'Project Light',
#  'Colorado Supreme Council of Islamic Affairs',
#  'Legacy Inc',
#  'WC and EJ Thornton Foundation',
#  'GIFT Ministries, Inc.',
#  'MOTHER OF GOD CHURCH',
#  'South Platte River Waterkeeper',
#  '#RestoreColorado',
#  'Love 4 Humanity',
#  'Hirschfeld Tower LRC',
#  'Cannabislistic Group',
#  'World Legacy Foundation',
#  'Globeville First Neighborhood Association',
#  'Responsible Wellington Inc.',
#  'The Shaylee Foundation',
#  'North Lincoln Homes LRC',
#  'Senegalese Childrens Aid Group',
#  'A Bridge To A Brighter Future',
#  'Bitwin Foundation Ltd',
#  'House Victory Fund',
#  'Gratitude Events Inc.',
#  'Black and Determined and Successful Students',
#  'Yes on Amendment B',
#  'Mile High Legends',
#  'Hope Valley Church',
#  'Disabled Culture',
#  'DU Duberstein Moot Court Team, Inc.',
#  'Skinner Middle School PTO',
#  'Tribe Ecology Foundation',
#  'The Realize Foundation, Inc.',
#  'NAATP Foundation for Recovery Science and Education',
#  'BIQIFengTai FOUNDATION LTD.',
#  'Locarity',
#  'Westwood Unidos',
#  'Denver Outreach Group',
#  'Walsh Manor LRC',
#  'Healthy Air and Water Colorado',
#  'Beautifully Broken',
#  'FUBAR',
#  'Beta Mu House Corp',
#  'Beads by TT',
#  'MySkin',
#  'Colorado Center for Aging, Inc.',
#  'The Karma House, Inc.',
#  'Greeks Addressing Problems',
#  'Thrive Community Building',
#  'Sound Formation Orchestra',
#  'The Underdog Family',
#  'Dukes of Windsor',
#  'Rocky Mountain Education Initiative',
#  'Eritrean Justice Seekers In Colorado',
#  'All Together Now',
#  'Healthier Colorado Small Donor Committee',
#  '5280 Elite Inc.',
#  'Denver Families for Public Schools',
#  'Denver Delta Chi Fraternity Inc',
#  'CONSCIOUS HARM REDUCTION SERVICES INC',
#  'colorado semicolon',
#  'Connect For Growth Colorado',
#  'Rams In The Bush Church',
#  'Slowly But Surely 303',
#  'Colorado PLA',
#  'bad books project',
#  '5280 Volunteer Coalition',
#  'Legacy Labyrinth Project',
#  'Carter House Foundation',
#  'The Lighthouse Nehemiah Project Corp',
#  'Broadway Lofts Condominium Association',
#  'Triumphant Life Ministries',
#  'KIDS ABOVE EVERYTHING',
#  'The West 52nd Avenue Condominium Association',
#  'Race Street Residences Association, Inc',
#  'The Rock Ministries, Inc.',
#  'The Dragons',
#  'MOORISH SCIENCE Temple of AMERICA INC.',
#  'Sean "Ranch" Lough Foundation',
#  'Denver for Denver',
#  'Fundacion Contigo Progresando FCP',
#  'FoundRising',
#  'Denver Park Trust',
#  'Dr. Caritha Education Foundation',
#  'The Schreiber Research Group',
#  'Wagapalooza',
#  'The STEAD School',
#  'Top Notch Sports',
#  'Portrait F54 at Stapleton Homeowners Association, Inc.',
#  'PARALLEL OUTLETS LUXURY FOUNDATION',
#  'Dignity Project Inc',
#  'colorado east african chambers of commerce',
#  "Sloans Lake Vietnamese Congregation of Jehovah's Witnesses",
#  'Jamie Torres for Council',
#  'Dreams Have Wings',
#  'Women Firefighters of Denver',
#  'Free Food Now',
#  'St. Louis Creek Association at Byers Peak Ranch West, Inc.',
#  'Gods Helping Hands, Inc.',
#  'Water for Generations',
#  'Power Producers BNI Chapter of Colorado',
#  'East 2nd Avenue Condominium Association',
#  'Hayden Family Foundation',
#  'EtherV Foundation',
#  'RMP Building Corporation',
#  'Manns Foundation',
#  'Project VOYCE',
#  'One Day Sober',
#  'Issachar Center',
#  'Elyria Globeville Swansea & Partners',
#  'CareExchange',
#  'Marijuana Industry Group Political Action Committee',
#  'Aurora and Adama Sister Cities Charity Association',
#  'Pentos Foundation',
#  'Barney Ford Heights LRC',
#  'inspirato foundation',
#  "Healing Life's Pains",
#  'Alpha Eta Iota',
#  'RiNo Gives Back',
#  'Not So Standard Deviations Incorporated',
#  'Craige Studio Inc.',
#  'Rose Medical Center Medical Staff Fund',
#  'The APC Foundation',
#  'Brink Conservancy',
#  'Infinite Seed',
#  'Critters in Classrooms, Inc.',
#  'Vitality, USA-KZ Animal Fund,Ltd',
#  'Farmstead Master Homeowners Association, Inc',
#  'Light CO2, Inc.',
#  'United Campus Workers-Communication Workers of America Colorado',
#  'Ride for Racial Justice',
#  'Colorado Bourbon & Rye Collectors Foundation',
#  'Institute of Brain Technologies',
#  'Colorado Emergency Food Network Inc.',
#  'Moving Mountains Animal Rescue',
#  'Lobos Volleyball Club',
#  'SeEds Inc.',
#  'Civic Health Coalition, Inc.',
#  'Denver Makes A Difference',
#  'Colorado Ethics Institute',
#  'Mile Hi Veterans Services',
#  'The Micah Foundation',
#  'LADY AVIATORS INC',
#  'Coloradans for Fair Housing',
#  'Victory Outreach Greater Denver',
#  'Aish Kodesh',
#  'ECKO HOMES.COM NON-PROFIT',
#  'UNIQUE HEARTS FOUNDATION, INC.',
#  'PediaClinic CARE Foundation',
#  'Platte Valley Homes & Dispersed East LRC',
#  'Syracuse Plaza LRC',
#  'Black sheep outreach',
#  'CHEER Colorado',
#  'International Self-Care Foundation',
#  'Park Hill Collective Impact, Inc',
#  'Garfield Apartments Inc.',
#  'The Next Chapter, Inc.',
#  'Ms. Jessica Foundation LLC',
#  'Team 180 Together',
#  'Thrive Owners Association',
#  'Dam Good Speakers',
#  'Climb Higher Colorado',
#  'The Rodney Washburn Scholarship Foundation',
#  'Institute for Cultural Heritage Imaging, Inc.',
#  'CO-SWEEP',
#  'Defy Ventures Colorado, Inc.',
#  'French American School of Denver',
#  'Peregrine Counseling and Wellness',
#  'Satori Condominium Association, Inc.',
#  'A Friend of Jack Rescue',
#  'Energy360, Inc.',
#  'My Yellow Shirt, Inc.',
#  'Medor Trust Fund',
#  'The Dormie Fund',
#  'Acme PPE Ltd',
#  'Benin Health Care Initiatives',
#  'Robin Technologies LLC',
#  'Beacon Network Schools Innovation Zone',
#  'New Terrace Homeowners Association',
#  'Transformations',
#  'Mulroy Apartments LRC',
#  'The Climbing Smiths Foundation, Inc.',
#  'Mending Roots Forest Project',
#  'The LoVVe Project',
#  'Urban Arts Music',
#  "America's House of Commons",
#  'Alnite Alliance',
#  'Shops on 6th Merchants Association',
#  'Colorado Organizations Responding to AIDS, Inc.',
#  'Approach III at Stapleton Community Association',
#  'NIC CONNECT Inc.',
#  'Colorado Change Agents (CCA)',
#  'COLORADO YOUNG BUSINESS OWNERS ASSOCIATION CORPORATION',
#  'Candy Girl Podcast',
#  'Word of Truth Christian Fellowship',
#  'The Ardent Grove Foundation',
#  'Restoring Balance Colorado',
#  'eLearning Consortium of Colorado',
#  'Immaculata Plaza, Inc.',
#  'Jewels and Dreams, Inc.',
#  'Joyce Lorraine Foundation',
#  'Eastern Colorado Council of Black Nurses Incorporated',
#  'Catalano',
#  'IA FOUNDATION LTD.',
#  'Disaster Support Foundation Inc',
#  'Justice and Mercy Legal Aid Center',
#  'PI KAPPA PHI EPSILON CHI HOUSING CORPORATION',
#  'GKC Development Foundation',
#  'The Helium Foundation',
#  '5318 Lowell Condominium Owners Association, Inc.',
#  'Denver Chapter, NSDAR',
#  'You be You Early Learning',
#  'Denver Loves Dogs',
#  'Pikes Peak Villains',
#  'Making A Way Community Outreach',
#  'Legacy Lofts Housing Corporation',
#  'Environmental and Animal Defense',
#  'Grid Gain Foundation Ltd.',
#  'Safe2 Ltd.',
#  'Dan Lewis Foundation for Brain Regeneration Research',
#  'Makimbilio',
#  'Colorado Shockers Baseball Club',
#  'Legacy Planned Community Association',
#  'The Coloradan Master Association',
#  'Americans for Nuclear Energy Inc.',
#  "KATHY'S KARTS OF CO",
#  'Colorado Sierra Club Independent Action',
#  'Reasons for Unity',
#  'Quarantine Keys, Inc.',
#  'Kindling Enterprises',
#  'The Church Denver Inc.',
#  "Karen's Hope Inc.",
#  'LittleJohn Produce Box Project',
#  'Income Tax & Financial Restructure For The Homeless, Inc',
#  'DJ Armstrong Foundation',
#  "NRG LABs , Nature's Real Gift's, Limited",
#  'Learn2Link',
#  'STOP COVAD (Crimes of Violence and Discrimination). Inc.',
#  'United Nations International Emergency Response Organization',
#  'Colorado Womens Rugby Association',
#  'Brotherhood Haven',
#  'Generations to Come',
#  'Aurora Community Protective Division',
#  "Mercy's Unlimited",
#  "Jacki's Fund",
#  'Greenland Communities Inc',
#  'Dr. W.O. Mays Sr. Community Mentorship & Apprenticeship Program',
#  'The Gathering at Cocoa Village Inc',
#  "MARIPOSA COURT HOMEOWNERS' ASSOCIATION, INC.",
#  'Desk Free Nation, Inc.',
#  'Do Better',
#  "Havok's Wolfpack",
#  'Range of Motion Project',
#  'United Africa Movement',
#  '2020 Racing DBA Physio Racing, a Colorado Nonprofit Corporation',
#  'Institute for Cannabis Wellness',
#  'YBC Charities',
#  'Columbine Homes LRC',
#  'CryptoCollision Community',
#  'Be The Change Program, Inc.',
#  'The Divine Care, Incorporated',
#  'Water Valley Vaults Owners Association',
#  'Fillmore Plaza Condominium Association',
#  'Knew Conscious Collective, Inc.',
#  'Royal Flower Trust',
#  'Corroded Dreams',
#  'Pretty Woman Ranch Corp.',
#  'DENVER METRO PICKLEBALL ASSOCIATION',
#  'Rural Leadership',
#  'A Good Start',
#  "Sloan's Lake Park Foundation",
#  'The REAL Church, Inc.',
#  'DOWNING 52X CONDOMINIUM ASSOCIATION',
#  'Rocky Mountain Alumni Club of Michigan State University',
#  'YAMAN FOUNDATION',
#  'Colorado Veterinary Medical Association Foundation',
#  'Trails at Crowfoot Master Owners Association, Inc.']

# %%
def lookup_agent(entity):
    return df.loc[df.entityname.str.lower() == entity.lower()] # [['agentfirstname', 'agentlastname']]

lookup_agent('Ruachis').T
# Out:
#                                             303
# entityid                            20201382904
# entityname                              Ruachis
# principaladdress1               4840 Wyandot st
# principalcity                            Denver
# principalstate                               CO
# principalzipcode                          80221
# principalcountry                             US
# entitystatus                      Good Standing
# jurisdictonofformation                       CO
# entitytype                Nonprofit Corporation
# agentorganizationname   DJR Memorial Foundation
# agentprincipaladdress1          4840 Wyandot st
# agentprincipaladdress2                      NaN
# agentprincipalcity                       Denver
# agentprincipalstate                          CO
# agentprincipalzipcode                     80221
# agentprincipalcountry                        US
# entityformdate          2020-04-28T00:00:00.000
# mailingaddress1                             NaN
# mailingcity                                 NaN
# mailingstate                                NaN
# mailingzipcode                              NaN
# mailingcountry                              NaN
# agentfirstname                              NaN
# agentlastname                               NaN
# agentmailingaddress1                        NaN
# agentmailingcity                            NaN
# agentmailingstate                           NaN
# agentmailingzipcode                         NaN
# agentmailingcountry                         NaN
# agentmiddlename                             NaN
# principaladdress2                           NaN
# agentmailingaddress2                        NaN
# mailingaddress2                             NaN
# agentsuffix                                 NaN

# %%
df.entitystatus.unique()
# Out:
# array(['Good Standing', 'Delinquent', 'Voluntarily Dissolved',
#        'Noncompliant'], dtype=object)
